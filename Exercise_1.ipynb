# %% [markdown]
# **Exercise 1**

# %% [markdown]
# 1 It does not print the fruit at the correct index, why is the returned result wrong?
#
# ***The problem lies in trying to use the fruit ID like a position number. while sets are unordered, so you cannot be sure in which order the items will appear.***
#
# 2 How could this be fixed?
#
# ***the fruits must be sent to the function as a list or tuple. for ex: name1 = id_to_fruit(1, ("apple", "orange", "melon", "kiwi", "strawberry"))***

# %%
from typing import Set,Tuple, List

# %%
# You can copy this code to your personal pipeline project or execute it here.
def id_to_fruit(fruit_id: int, fruits: Set[str]) -> str:
    idx = 0
    for fruit in fruits:
        if fruit_id == idx:
            return fruit
        idx += 1
    raise RuntimeError(f"Fruit with id {fruit_id} does not exist")

# %%
name1 = id_to_fruit(1, {"apple", "orange", "melon", "kiwi", "strawberry"})
name3 = id_to_fruit(3, {"apple", "orange", "melon", "kiwi", "strawberry"})
name4 = id_to_fruit(4, {"apple", "orange", "melon", "kiwi", "strawberry"})
print(name1)
print(name3)
print(name4)
# Out:
# melon
# orange
# kiwi

# %% [markdown]
# # Corrected code:

# %%
# Bug fixed
name1 = id_to_fruit(1, ("apple", "orange", "melon", "kiwi", "strawberry"))
name3 = id_to_fruit(3, ("apple", "orange", "melon", "kiwi", "strawberry"))
name4 = id_to_fruit(4, ("apple", "orange", "melon", "kiwi", "strawberry"))

print(name1)
print(name3)
print(name4)
# Out:
# orange
# kiwi
# strawberry
